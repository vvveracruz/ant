# %%
# importing local ant module
import sys
import os
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"/")
import ant

# normal imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
f=lambda v: v**2-2*v*(1+np.sinh(v))*np.cosh(v)+1+2*np.sinh(v)

# %%
df=pd.DataFrame(index=[x/100 for x in range(-100, 100)])
df['f']=df.index.map(f)
ax=df.plot()
plt.axhline(y=0, color='gray', linewidth=0.75)

# %%
import numpy as np
from skimage import measure
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

xl = np.linspace(-3, 3, 50)
X, Y, Z = np.meshgrid(xl, xl, xl)
F = goursat_tangle(X, Y, Z)

verts, faces, normals, values = measure.marching_cubes(F, 0, spacing=[np.diff(xl)[0]]*3)
verts -= 3
# Out:
# <ipython-input-24-546681c68024>:47: RuntimeWarning: divide by zero encountered in double_scalars
#   return a**2/x+b**2/y+c**2/z
# /usr/local/lib/python3.9/site-packages/matplotlib/contour.py:1494: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# /usr/local/lib/python3.9/site-packages/matplotlib/contour.py:1495: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# <ipython-input-24-546681c68024>:19: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# <ipython-input-24-546681c68024>:25: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y')
# <ipython-input-24-546681c68024>:30: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')
